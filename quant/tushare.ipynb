# %%
import pandas as pd
import numpy as np
import tushare as ts
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#msdf=ts.get_money_supply_bal()

# %%
#type(ts.get_money_supply_bal())
# Out:
# pandas.core.frame.DataFrame

# %%
#msdf.describe()
# Out:
#         year        m2        m1        m0         cd        qm ftd  sd rests
# count     28        28        28        28         28        28  28  28    28
# unique    28        28        28        28         28        28  25  26    25
# top     1992  15293.40  28514.80  24032.00  122184.90  36763.40  --  --    --
# freq       1         1         1         1          1         1   4   3     4

# %%
#msdf.to_csv("m2.csv")

# %%
msdf=pd.read_csv("m2.csv")

# %%
msdf.columns
# Out:
# Index(['Unnamed: 0', 'year', 'm2', 'm1', 'm0', 'cd', 'qm', 'ftd', 'sd',
#        'rests'],
#       dtype='object')

# %%
msdf.set_index=msdf['year']

# %%
del msdf['Unnamed: 0']

# %%
msdf.dtypes
# plot()
# Out:
# year       int64
# m2       float64
# m1       float64
# m0       float64
# cd       float64
# qm       float64
# ftd      float64
# sd       float64
# rests    float64
# dtype: object

# %%
msdf.year=pd.to_numeric(msdf.year,errors="coerce")
msdf.m2=pd.to_numeric(msdf.m2,errors="coerce")
msdf.m1=pd.to_numeric(msdf.m1,errors="coerce")
msdf.m0=pd.to_numeric(msdf.m0,errors="coerce")
msdf.cd=pd.to_numeric(msdf.cd,errors="coerce")
msdf.qm=pd.to_numeric(msdf.qm,errors="coerce")
msdf.ftd=pd.to_numeric(msdf.ftd,errors="coerce")
msdf.sd=pd.to_numeric(msdf.sd,errors="coerce")
msdf.rests=pd.to_numeric(msdf.rests,errors="coerce")

# %%
msdf.dtypes
# Out:
# year       int64
# m2       float64
# m1       float64
# m0       float64
# cd       float64
# qm       float64
# ftd      float64
# sd       float64
# rests    float64
# dtype: object

# %%
msdf
# Out:
#     year         m2        m1       m0        cd         qm       ftd  \
# 0   2017  1690235.3  543790.0  70646.0  473144.5  1132978.4  320196.2
# 1   2016  1550067.0  486557.0  68304.0  418253.4  1063509.4  307989.6
# 2   2015  1392278.0  400953.0  63217.0  337736.9   991324.7  288240.7
# 3   2014  1228375.0  348056.0  60260.0  287796.9   880318.4  264055.7
# 4   2013  1106525.0  337291.0  58574.0  278716.6   769233.9  232696.6
# 5   2012   974149.0  308664.0  54660.0  254004.5   665484.6  195940.1
# 6   2011   851591.0  289848.0  50748.0  239099.2   561743.2  166616.0
# 7   2010   725852.0  266622.0  44628.0  221993.4   459230.3  105858.7
# 8   2009   610225.0  221446.0  38247.0  183198.8   388778.7   84819.5
# 9   2008   475167.0  166217.0  34219.0  131998.2   308949.5   60103.1
# 10  2007   403442.0  152560.0  30375.0  122184.9   250882.1   46932.5
# 11  2006   345578.0  126028.0  27073.0   98962.5   219568.5       NaN
# ...

# %%
msdf.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
msdf.sort_index(ascending=False)
# Out:
#     year         m2        m1       m0        cd         qm       ftd  \
# 27  1990    15293.4    6950.7   2644.4    4306.3     8342.7       NaN
# 26  1991    19349.9    8633.3   3177.8    5455.5    10716.6       NaN
# 25  1992    25402.2   11731.5   4336.0    7395.2    13670.7       NaN
# 24  1993    34879.8   16280.4   5864.7   10415.7    18599.4    1247.9
# 23  1994    46923.5   20540.7   7288.6   13252.1    26382.8    1943.1
# 22  1995    60750.5   23987.1   7885.3   16101.8    36763.4    3324.2
# 21  1996    76094.9   28514.8   8802.0   19712.8    47580.1    5041.9
# 20  1997    90995.3   34826.3  10177.6   24648.7    56169.0    6738.5
# 19  1998   104498.5   38953.7  11204.2   27749.5    65544.9    8301.9
# 18  1999   119897.9   45837.3  13455.5   32381.8    74060.6    9476.8
# 17  2000   134610.4   53147.2  14652.7   38494.5    81463.2   11261.1
# 16  2001   158302.0   59872.0  15689.0   44182.8    98430.3   14180.1
# ...

# %%
msdf.drop?

# %%
msdf.plot()

# %%
msdf=pd.DataFrame(msdf, index=msdf['year'])

# %%
msdf
# Out:
#       year  m2  m1  m0  cd  qm  ftd  sd  rests
# year
# 2017   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2016   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2015   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2014   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2013   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2012   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2011   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2010   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2009   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2008   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2007   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2006   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2005   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2004   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2003   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2002   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2001   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 2000   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# 1999   NaN NaN NaN NaN NaN NaN  NaN NaN    NaN
# ...
